# %% [markdown]
# # This notebook
#
# * Explores the x and y parameters in the plot
#     * Serialized into functions
#
# * Simplified with imports from scripts

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import pickle

import sys
import os

sys.path.append(os.path.abspath('/freya/ptmp/mpa/wuze/multiphase_turb'))
import codes
from codes.timescales import *
from codes.funcs import *
from codes.plotting.params import *
from codes.jason import plotting_def, plot_prettier

plotting_def()
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import cmasher as cmr
# Out:
# Codes imported

# %%
_ = get_datamd(fname="/ptmp/mpa/wuze/multiphase_turb/data/240626_0.8_16000/cloud/Turb.out2.00000.athdf", verbose=True)
# Out:
# ['Coordinates', 'DatasetNames', 'MaxLevel', 'MeshBlockSize', 'NumCycles', 'NumMeshBlocks', 'NumVariables', 'RootGridSize', 'RootGridX1', 'RootGridX2', 'RootGridX3', 'Time', 'VariableNames', 'x1f', 'x1v', 'x2f', 'x2v', 'x3f', 'x3v', 'rho', 'press', 'vel1', 'vel2', 'vel3', 'r0']

# %% [markdown]
# # BW plot

# %%
plot_point_bw(trial = '240626_0.3_8000', verbose = False)
# Out:
# /freya/ptmp/mpa/wuze/multiphase_turb/codes/timescales.py:370: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   sc = plt.scatter(x, y, marker='o', vmin=-0.3, vmax=0.3, ec='k', fc='None')
# /freya/ptmp/mpa/wuze/multiphase_turb/codes/timescales.py:386: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Color plot

# %% [markdown]
# ## Check pressure floor

# %%
# # 0.0005 is the default value
# pfloor_prim = 0.0005
# plot_pressure_floor(trial='240628_0.6_16000000', pfloor=pfloor_prim, file_ind=-1)

# %% [markdown]
# ## Add params

# %%
# plot the timescales

from codes.timescales import *

plot_cooling(trial='240711_0.4_16000', shade=True, plot_which=[1, 0, 1])

# %%
from codes.timescales import *

plot_cooling_panel(trial='240711_0.4_16000', shade=True)
# Out:
# /freya/ptmp/mpa/wuze/multiphase_turb/codes/timescales.py:218: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend(loc='lower left', bbox_to_anchor=(0.6, 0), fontsize=fs, alignment='left')

# %%
from codes.timescales import *

plot_cooling_panel_hist(trial='240711_0.4_16000', shade=True, snapshot=22)

# %%
from codes.timescales import *
trial, trial_x_val, trial_y_val, rp, l_shatter_min, log_cold_frac, log_warm_frac, t_cool_mix, t_cool_min, grid_dim, stop_time =\
plot_point_color(trial='240709_0.6_16000',
                 verbose=False, cg_st_epoch=0, return_cropped=False)
# Out:
# 9.325612894925658e-09 [1.32589e-09 1.32525e-09 1.32347e-09 ... 3.29855e-09 3.29586e-09
#  3.29587e-09] [0.00000e+00 5.71056e-14 2.15944e-12 ... 6.00441e-09 6.00715e-09
#  6.00712e-09]
# Cropped for hot mass
# /freya/ptmp/mpa/wuze/multiphase_turb/codes/timescales.py:373: RuntimeWarning: divide by zero encountered in log10
#   return np.log10(cg_mass_cropped[:hot_fill_ind] / cg_mass_cropped[cg_st_epoch]), np.log10(wg_mass_cropped[:hot_fill_ind] / cg_mass_cropped[cg_st_epoch]), stop_time_cc
# /freya/ptmp/mpa/wuze/multiphase_turb/codes/timescales.py:474: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
from codes.timescales import *
save_params(trial, trial_x_val, trial_y_val, rp, l_shatter_min, log_cold_frac, log_warm_frac, t_cool_mix, t_cool_min, grid_dim, stop_time,
            csvpath=f'/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv')
# Out:
# 240613_0.1_10
#                    trial    x_mach             y        r_cl        l_shat  \
# 0         240702_0.6_320  0.599142  3.201322e+02    0.000800  2.498968e-06
# 1          240620_0.5_16  0.487757  1.600661e+01    0.000040  2.498968e-06
# 2          240620_0.8_32  0.832884  3.201322e+01    0.000080  2.498968e-06
# 3          240620_0.6_32  0.615851  3.201322e+01    0.000080  2.498968e-06
# 4        240708_0.6_1600  0.599142  1.600661e+03    0.004000  2.498968e-06
# 5   240709_0.6_160000000  0.607674  1.600661e+08    0.040000  2.498968e-10
# 6     240709_0.6_1600000  0.607674  1.600661e+06    0.000400  2.498968e-10
# 7       240709_0.6_16000  0.607674  1.600661e+04    0.000004  2.498968e-10
# 8         240711_0.4_320  0.415252  3.201322e+02    0.000800  2.498968e-06
# 9        240711_0.4_1600  0.415252  1.600661e+03    0.004000  2.498968e-06
# 10      240711_0.4_16000  0.400000  1.600661e+04    0.040000  2.498968e-06
# 11    240711_0.4_1600000  0.415252  1.600661e+06    4.000000  2.498968e-06
# 12  240711_0.4_160000000  0.400000  1.600661e+08  400.000000  2.498968e-06
# 13        240711_0.8_320  0.821217  3.201322e+02    0.000800  2.498968e-06
# 14       240711_0.8_1600  0.821217  1.600661e+03    0.004000  2.498968e-06
# 15      240711_0.8_16000  0.821217  1.600661e+04    0.040000  2.498968e-06
# 16    240711_0.8_1600000  0.821217  1.600661e+06    4.000000  2.498968e-06
# 17  240711_0.8_160000000  0.821217  1.600661e+08  400.000000  2.498968e-06
# 18         240715_0.4_16  0.400000  1.600661e+01    0.000040  2.498968e-06
# 19         240715_0.6_16  0.600000  1.600661e+01    0.000040  2.498968e-06
# 20         240715_0.8_16  0.800000  1.600661e+01    0.000040  2.498968e-06
# 21     240715_0.4_160000  0.400000  1.600661e+05    0.400000  2.498968e-06
# 22     240715_0.6_160000  0.600000  1.600661e+05    0.400000  2.498968e-06
# 23     240715_0.8_160000  0.800000  1.600661e+05    0.400000  2.498968e-06
# 24      240716_0.4_32000  0.400000  3.201322e+04    0.080000  2.498968e-06
# 25      240716_0.8_32000  0.800000  3.201322e+04    0.080000  2.498968e-06
# 26      240716_0.4_64000  0.400000  6.402643e+04    0.160000  2.498968e-06
# 27      240716_0.8_64000  0.800000  6.402643e+04    0.160000  2.498968e-06
# 28       240716_0.4_8000  0.400000  8.003304e+03    0.020000  2.498968e-06
# 29       240716_0.8_8000  0.800000  8.003304e+03    0.020000  2.498968e-06
# 30       240716_0.4_4000  0.400000  4.001652e+03    0.010000  2.498968e-06
# 31       240716_0.8_4000  0.800000  4.001652e+03    0.010000  2.498968e-06
# 32         240613_0.1_10  0.600000  1.600661e+04    0.000004  2.498968e-10
#
#     log_cold_mass  log_warm_mass  T_cloud  T_floor     chi    t_cool_mix  \
# 0       -5.326345      -0.326798    800.0    800.0  5000.0  7.212244e-03
# 1       -1.000000      -1.000000    800.0    800.0  5000.0  7.212244e-03
# 2       -1.000000      -1.000000    800.0    800.0  5000.0  7.212244e-03
# 3       -1.000000      -1.000000    800.0    800.0  5000.0  7.212244e-03
# 4       -0.622606       0.801879    800.0    800.0  5000.0  7.212244e-03
# 5        0.845271      -1.513085    800.0    800.0  5000.0  7.212244e-07
# 6        0.770639       0.055332    800.0    800.0  5000.0  7.212244e-07
# 7        0.395463       0.656159    800.0    800.0  5000.0  7.212244e-07
# 8       -3.828117       0.063734    800.0    800.0  5000.0  7.212244e-03
# 9       -1.089092       0.852564    800.0    800.0  5000.0  7.212244e-03
# 10       0.203884       0.726518    800.0    800.0  5000.0  7.212244e-03
# 11       0.837699      -0.384559    800.0    800.0  5000.0  7.212244e-03
# 12       0.827629      -0.698360    800.0    800.0  5000.0  7.212244e-03
# 13      -3.277009      -0.126643    800.0    800.0  5000.0  7.212244e-03
# 14      -3.029536       0.488297    800.0    800.0  5000.0  7.212244e-03
# 15       0.391218       0.791743    800.0    800.0  5000.0  7.212244e-03
# 16       0.854197       0.202071    800.0    800.0  5000.0  7.212244e-03
# 17       0.930973      -0.678022    800.0    800.0  5000.0  7.212244e-03
# 18      -1.000000      -0.238748    800.0    800.0  5000.0  7.212244e-03
# 19      -1.000000      -0.440561    800.0    800.0  5000.0  7.212244e-03
# 20      -2.915549      -0.567952    800.0    800.0  5000.0  7.212244e-03
# 21       0.767988       0.155951    800.0    800.0  5000.0  7.212244e-03
# 22       0.628614       0.400748    800.0    800.0  5000.0  7.212244e-03
# 23       0.662180       0.616823    800.0    800.0  5000.0  7.212244e-03
# 24       0.699740       0.358119    800.0    800.0  5000.0  7.212244e-03
# 25      -0.004870       0.888191    800.0    800.0  5000.0  7.212244e-03
# 26       0.593731       0.527538    800.0    800.0  5000.0  7.212244e-03
# 27       0.257256       0.839944    800.0    800.0  5000.0  7.212244e-03
# 28       0.528690       0.590815    800.0    800.0  5000.0  7.212244e-03
# 29      -0.471706       0.918949    800.0    800.0  5000.0  7.212244e-03
# 30      -0.687928       0.849453    800.0    800.0  5000.0  7.212244e-03
# 31      -0.855712       0.925807    800.0    800.0  5000.0  7.212244e-03
# 32       0.074249       0.739791    800.0    800.0  5000.0  7.212244e-07
#
#       t_cool_min  grid_dim  stop_time
# 0   1.217175e-04     256.0   7.121329
# 1   1.217175e-04     128.0  20.000000
# 2   1.217175e-04     128.0  12.942168
# 3   1.217175e-04     128.0  12.378085
# 4   1.217175e-04     256.0   7.121320
# 5   1.217175e-08     256.0   2.526015
# 6   1.217175e-08     256.0   7.121296
# 7   1.217175e-08     256.0   7.121296
# 8   1.217175e-04     256.0   2.329030
# 9   1.217175e-04     256.0   3.124198
# 10  1.217175e-04     256.0   2.060112
# 11  1.217175e-04     256.0   2.600102
# 12  1.217175e-04     256.0   1.383186
# 13  1.217175e-04     256.0   2.473186
# 14  1.217175e-04     256.0   3.405998
# 15  1.217175e-04     256.0   4.500126
# 16  1.217175e-04     256.0   3.000131
# 17  1.217175e-04     256.0   1.700172
# 18  1.217175e-04     256.0   2.446120
# 19  1.217175e-04     256.0   2.379081
# 20  1.217175e-04     256.0   2.560111
# 21  1.217175e-04     256.0   2.700120
# 22  1.217175e-04     256.0   4.400145
# 23  1.217175e-04     256.0   2.600067
# 24  1.217175e-04     256.0   4.600157
# 25  1.217175e-04     256.0   3.900026
# 26  1.217175e-04     256.0   2.600058
# 27  1.217175e-04     256.0   3.800087
# 28  1.217175e-04     256.0   4.826160
# 29  1.217175e-04     256.0   4.000215
# 30  1.217175e-04     256.0   4.000057
# 31  1.217175e-04     256.0   3.666057
# 32  1.217175e-08     256.0   2.411996

# %% [markdown]
# # All params
#
# Plot all params from the saved .csv file
# If same in parameter space, plot the one with larger timescale instead

# %%
from codes.plotting.params import *
plot_params_all(csvpath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv', switch_phase='cold')
# Out:
# /freya/ptmp/mpa/wuze/multiphase_turb/codes/plotting/params_plots.py:93: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # All params from file

# %%
from codes.plotting.params import *
plot_params_all_file(csvpath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv')
# Out:
# 7.5087403921992245e-06 [1.10896e-06 1.10140e-06 1.09418e-06 ... 8.31767e-12 5.43405e-12
#  5.23083e-12] [0.00000e+00 6.53472e-09 1.48210e-08 ... 5.22137e-07 5.22289e-07
#  5.22538e-07]
# /tmp/ipykernel_39227/407278969.py:389: RuntimeWarning: divide by zero encountered in log10
#   return np.log10(cg_mass_cropped[:hot_fill_ind] / cg_mass_cropped[cg_st_epoch]), np.log10(wg_mass_cropped[:hot_fill_ind] / cg_mass_cropped[cg_st_epoch]), stop_time_cc
# 1.7060473891377334e-10 [1.19430e-10 1.19379e-10 1.19325e-10 ... 0.00000e+00 0.00000e+00
#  0.00000e+00] [0.000e+00 0.000e+00 1.063e-15 ... 0.000e+00 0.000e+00 0.000e+00]
# 1.6449684352155917e-09 [1.23562e-09 1.23520e-09 1.23461e-09 ... 0.00000e+00 0.00000e+00
#  0.00000e+00] [0.00000e+00 0.00000e+00 2.84215e-14 ... 0.00000e+00 0.00000e+00
#  0.00000e+00]
# 1.3788429533534598e-09 [9.69444e-10 9.69048e-10 9.68546e-10 ... 0.00000e+00 0.00000e+00
#  0.00000e+00] [0.00000e+00 0.00000e+00 4.80869e-14 ... 0.00000e+00 0.00000e+00
#  0.00000e+00]
# 0.0009385925490249032 [1.38620e-04 1.37674e-04 1.36770e-04 ... 3.28098e-05 3.31106e-05
#  3.30537e-05] [0.00000e+00 9.55747e-07 1.85955e-06 ... 8.78740e-04 8.78372e-04
#  8.78426e-04]
# Cropped for hot mass
# 9325.612894925642 [1325.89 1325.94 1326.03 ... 9284.32 9285.39 9284.92] [ 0.         0.0675029  0.        ... 41.2806    40.218     40.6839   ]
# Cropped for hot mass
# 0.009325612894925658 [0.00132589 0.00132341 0.00132144 ... 0.00781934 0.00781982 0.00781892] [0.00000e+00 2.59410e-06 4.57883e-06 ... 1.50563e-03 1.50514e-03
#  1.50605e-03]
# Cropped for hot mass
# 9.325612894925658e-09 [1.32589e-09 1.32525e-09 1.32347e-09 ... 3.29855e-09 3.29586e-09
#  3.29587e-09] [0.00000e+00 5.71056e-14 2.15944e-12 ... 6.00441e-09 6.00715e-09
#  6.00712e-09]
# Cropped for hot mass
# 7.416505631588931e-06 [1.01671e-06 1.01083e-06 1.00396e-06 ... 2.24070e-10 1.64506e-10
#  1.51036e-10] [0.00000e+00 5.29822e-09 1.27749e-08 ... 1.17608e-06 1.17841e-06
#  1.17742e-06]
# 0.0009270632039486153 [1.27089e-04 1.26348e-04 1.25487e-04 ... 1.03013e-05 1.03372e-05
#  1.03518e-05] [0.00000e+00 7.48494e-07 1.60935e-06 ... 9.05037e-04 9.05031e-04
#  9.05048e-04]
# Cropped for hot mass
# 0.9270632039486141 [0.127089 0.126342 0.125481 ... 0.178251 0.177769 0.177546] [0.         0.00075649 0.00161874 ... 0.748265   0.748744   0.748967  ]
# Cropped for hot mass
# 927063.2039486156 [127089. 126503. 126804. ... 874382. 874476. 874595.] [    0.      595.986   297.997 ... 52638.6   52545.4   52426.3  ]
# Cropped for hot mass
# 927063203948.6161 [1.27089e+11 1.26893e+11 1.27102e+11 ... 9.21835e+11 9.21957e+11
#  9.22090e+11] [0.00000e+00 2.06005e+08 0.00000e+00 ... 5.22802e+09 5.10610e+09
#  4.97322e+09]
# Cropped for hot mass
# 7.226428996864202e-06 [8.26618e-07 8.25831e-07 8.24428e-07 ... 4.87979e-10 4.77141e-10
#  4.36813e-10] [0.00000e+00 0.00000e+00 5.80346e-10 ... 6.18800e-07 6.17511e-07
#  6.17536e-07]
# 0.0009033036246080226 [1.03327e-04 1.03228e-04 1.03048e-04 ... 9.37915e-08 1.02440e-07
#  9.65335e-08] [0.00000e+00 0.00000e+00 1.36466e-07 ... 3.17600e-04 3.17963e-04
#  3.18061e-04]
# 0.9033036246080247 [0.103327 0.10322  0.103022 ... 0.252825 0.253445 0.25435 ] [0.00000e+00 2.89964e-05 2.72010e-04 ... 6.41218e-01 6.40570e-01
#  6.39671e-01]
# Cropped for hot mass
# 903303.6246080248 [103327. 103166. 103042. ... 738976. 739316. 738603.] [0.00000e+00 1.47619e+02 2.86176e+02 ... 1.64171e+05 1.63834e+05
#  1.64545e+05]
# Cropped for hot mass
# 903303624608.0236 [1.03327e+11 1.03172e+11 1.03287e+11 ... 8.83867e+11 8.83139e+11
#  8.81428e+11] [0.00000e+00 1.43329e+08 4.00262e+07 ... 1.92255e+10 1.99650e+10
#  2.16866e+10]
# Cropped for hot mass
# 9.270632039486149e-10 [1.27089e-10 1.27009e-10 1.26901e-10 ... 0.00000e+00 0.00000e+00
#  0.00000e+00] [0.00000e+00 0.00000e+00 1.53786e-14 ... 7.34394e-11 7.34209e-11
#  7.33433e-11]
# 9.385925490249031e-10 [1.38620e-10 1.38555e-10 1.38460e-10 ... 0.00000e+00 0.00000e+00
#  0.00000e+00] [0.00000e+00 0.00000e+00 0.00000e+00 ... 5.03950e-11 5.03050e-11
#  5.02649e-11]
# 9.033036246080252e-10 [1.03327e-10 1.03292e-10 1.03250e-10 ... 1.27487e-13 1.20067e-13
#  1.25506e-13] [0.00000e+00 0.00000e+00 0.00000e+00 ... 2.78200e-11 2.79603e-11
#  2.79423e-11]
# 927.0632039486114 [127.089 126.34  125.829 ... 744.02  744.52  744.897] [  0.        0.759     1.27174 ... 182.875   182.374   181.995  ]
# Cropped for hot mass
# 938.5925490249042 [138.62  137.673 137.046 ... 588.772 589.023 589.44 ] [  0.         0.959607   1.58704  ... 349.472    349.22     348.798   ]
# Cropped for hot mass
# 903.3036246080233 [103.327 103.191 102.98  ... 476.174 475.484 474.672] [0.00000e+00 1.03948e-01 3.45046e-01 ... 4.26100e+02 4.26792e+02
#  4.27599e+02]
# Cropped for hot mass
# 7.416505631588921 [1.01671 1.01073 1.00384 ... 5.10042 5.09593 5.09257] [0.         0.00606208 0.0129627  ... 2.31125    2.31574    2.31908   ]
# Cropped for hot mass
# 7.22642899686419 [0.826618 0.825714 0.824089 ... 0.817205 0.817902 0.8174  ] [0.00000e+00 3.55715e-04 2.38665e-03 ... 6.39030e+00 6.38948e+00
#  6.38993e+00]
# Cropped for hot mass
# 59.33204505271135 [ 8.13368  8.08577  8.03463 ... 31.9108  31.9186  31.9167 ] [ 0.         0.0485682  0.0998016 ... 27.4108    27.4028    27.4047   ]
# Cropped for hot mass
# 57.81143197491355 [ 6.61295  6.60516  6.59188 ... 11.9462  11.9447  11.9578 ] [0.00000e+00 4.12504e-03 2.03985e-02 ... 4.57576e+01 4.57589e+01
#  4.57445e+01]
# Cropped for hot mass
# 0.11588290049357683 [0.0158861 0.0157929 0.0156852 ... 0.0535957 0.053578  0.053667 ] [0.00000e+00 9.43891e-05 2.02134e-04 ... 6.19911e-02 6.20088e-02
#  6.19202e-02]
# Cropped for hot mass
# 0.11291295307600309 [0.0129159  0.0129031  0.012879   ... 0.00440786 0.00438751 0.00435932] [0.00000e+00 2.13590e-06 3.09236e-05 ... 1.07107e-01 1.07136e-01
#  1.07170e-01]
# Cropped for hot mass
# 0.014485362561697105 [0.00198576 0.00197414 0.00196068 ... 0.00040819 0.00040787 0.00040738] [0.00000e+00 1.17628e-05 2.52256e-05 ... 1.40394e-02 1.40397e-02
#  1.40404e-02]
# Cropped for hot mass
# 0.014114119134500397 [0.00161449 0.00161292 0.00161    ... 0.00358966 0.00358361 0.00359334] [0.00000e+00 7.96418e-08 3.45385e-06 ... 9.76331e-03 9.76888e-03
#  9.75888e-03]
# Cropped for hot mass
# /tmp/ipykernel_39227/975332979.py:101: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# ## Single plane

# %%
import cmasher as cmr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cm_cold = cmr.get_sub_cmap('cmr.viola_r', 0.25, 0.75)  #plt.colormaps['bwr_r']  # diverging colormap for cold gas
cm_warm = cmr.combine_cmaps(cmr.get_sub_cmap('cmr.wildfire', 0.5, 0.75), cmr.get_sub_cmap('cmr.wildfire', 0.75, 1), nodes=[1/3])#cmr.get_sub_cmap('cmr.ember', 0.6, 1, N=15)  #cmr.get_sub_cmap('cmr.ember', 0.3, 1, N=2)  #plt.colormaps['Oranges']  # diverging colormap for cold gas
ms = 50

from codes.plotting.params import *
plot_params_all_file_s(csvpath='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv',
                       cm_cold=cm_cold, cm_warm=cm_warm, ms=ms,
                       show_text=True,  # show text of the log mass fraction
                       plot_ana=[1, 1, 1],  # analytical lines as predicted: [warm1, cold, warm2]
                       real_mach=True)  # use the actual mach number
# Out:
# Error in callback <function _draw_all_if_interactive at 0x1471c502c900> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt

# %% [markdown]
# ## Quick plot

# %%
cm_cold = cmr.get_sub_cmap('cmr.viola_r', 0.25, 0.75)  #plt.colormaps['bwr_r']  # diverging colormap for cold gas
cm_warm = cmr.combine_cmaps(cmr.get_sub_cmap('cmr.wildfire', 0.5, 0.75), cmr.get_sub_cmap('cmr.wildfire', 0.75, 1), nodes=[1/3])#cmr.get_sub_cmap('cmr.ember', 0.6, 1, N=15)  #cmr.get_sub_cmap('cmr.ember', 0.3, 1, N=2)  #plt.colormaps['Oranges']  # diverging colormap for cold gas
ms = 50

# load an rp
datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/240711_0.4_1600'
with open(f'{datapath}/params.pickle', 'rb') as handle:
    rp = pickle.load(handle)

from codes.plotting.params import *
plot_params_all_file_save(pickle_path='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.pkl',
                          cm_cold=cm_cold, cm_warm=cm_warm, ms=ms,
                          show_text=True,  # show text of the log mass fraction
                          plot_ana=[1, 1, 1])  # analytical lines as predicted: [warm1, cold, warm2]
# Out:
# 0.31088619527842865
# [0.00000000e+00 2.59825613e+04 5.37350196e+04 8.33477969e+04
#  1.14915422e+05 1.48536704e+05 1.84314917e+05 2.22357984e+05
#  2.62778682e+05 3.05694839e+05 3.51229554e+05 3.99511414e+05
#  4.50674730e+05 5.04859773e+05 5.62213029e+05 6.22887455e+05
#  6.87042752e+05 7.54845648e+05 8.26470190e+05 9.02098050e+05
#  9.81918841e+05 1.06613045e+06 1.15493937e+06 1.24856109e+06
#  1.34722042e+06 1.45115191e+06 1.56060025e+06 1.67582067e+06
#  1.79707940e+06 1.92465409e+06 2.05883431e+06 2.19992204e+06
#  2.34823215e+06 2.50409296e+06 2.66784675e+06 2.83985038e+06
#  3.02047587e+06 3.21011099e+06 3.40915994e+06 3.61804397e+06
#  3.83720216e+06 4.06709203e+06 4.30819039e+06 4.56099407e+06
#  4.82602073e+06 5.10380972e+06 5.39492296e+06 5.69994583e+06
#  6.01948813e+06 6.35418506e+06 6.70469827e+06 7.07171687e+06
#  7.45595858e+06 7.85817086e+06 8.27913210e+06 8.71965287e+06
#  9.18057723e+06 9.66278400e+06 1.01671882e+07 1.06947426e+07
#  1.12464389e+07 1.18233098e+07 1.24264300e+07 1.30569185e+07
#  1.37159398e+07 1.44047063e+07 1.51244797e+07 1.58765730e+07
#  1.66623529e+07 1.74832417e+07 1.83407193e+07 1.92363260e+07
#  2.01716642e+07 2.11484016e+07 2.21682731e+07 2.32330839e+07
#  2.43447122e+07 2.55051118e+07 2.67163155e+07 2.79804379e+07
#  2.92996787e+07 3.06763260e+07 3.21127599e+07 3.36114560e+07
#  3.51749893e+07 3.68060379e+07 3.85073869e+07 4.02819332e+07
#  4.21326891e+07 4.40627875e+07 4.60754860e+07 4.81741724e+07
#  5.03623692e+07 5.26437391e+07 5.50220906e+07 5.75013835e+07
#  6.00857347e+07 6.27794247e+07 6.55869036e+07 6.85127976e+07]

# %% [markdown]
# ## Plot timescale at mach

# %%
cm_cold = cmr.get_sub_cmap('cmr.viola_r', 0.25, 0.75)  #plt.colormaps['bwr_r']  # diverging colormap for cold gas
cm_warm = cmr.combine_cmaps(cmr.get_sub_cmap('cmr.wildfire', 0.5, 0.75), cmr.get_sub_cmap('cmr.wildfire', 0.75, 1), nodes=[1/3])#cmr.get_sub_cmap('cmr.ember', 0.6, 1, N=15)  #cmr.get_sub_cmap('cmr.ember', 0.3, 1, N=2)  #plt.colormaps['Oranges']  # diverging colormap for cold gas
ms = 50

from codes.plotting.params import *
plot_timescale_mach(pickle_path='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.pkl',
                    mach=0.8, pt_y=1e7,
                    cm_cold=cm_cold, cm_warm=cm_warm, ms=ms,
                    plot_ana=[1, 1, 1])  # analytical lines as predicted: [warm1, cold, warm2]

# %%
def plot_timescale_mach(pickle_path = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.pkl',
                        ms = 30, plot_ana = False, mach = 0.8, pt_y = 1e4,
                        cm_cold = None, cm_warm = None, verbose = False):
    from matplotlib.gridspec import GridSpec
    import pandas as pd

    with open(pickle_path, 'rb') as handle:
        plt_elements = pickle.load(handle)

    # initialize the plot
    fig, ax = plt.subplots(figsize=(4.5, 4))
    # make the markers
    lmarker = MarkerStyle("o", fillstyle="left")
    rmarker = MarkerStyle("o", fillstyle="right")
    
    """Plot both cold & hot gas plots from the pickle file"""
    i = 0
    ylist = []
    scs = [None, None]
    for marker, cm in \
    zip([lmarker, rmarker], [cm_cold, cm_warm]):
        [xs, ys, pt_sizes, log_frac_means] = plt_elements[i]
        for x, y, pt_size, log_frac_mean in zip(xs, ys, pt_sizes, log_frac_means):
            # plot only if within mach range
            if (x < mach+0.1) and (x > mach-0.1):
                # plot the point
                if i:  # warm, make linear
                    scs[i] = ax.scatter(y, pt_y, marker=marker, s=pt_size,
                                        c=log_frac_mean, vmin=0, vmax=1, ec='k', cmap=cm)
                else:  # cold, colorbar in log
                    scs[i] = ax.scatter(y, pt_y, marker=marker, s=pt_size,
                                        c=log_frac_mean, vmin=-0.3, vmax=0.3, ec='k', cmap=cm)

                ylist.append(y)
        i += 1  # update the savescounter

    """Plot the analytic line"""
    if plot_ana:
        """warm analytical line 1"""
        if plot_ana[0]:
            ax.axvline(1e3, lw=2, ls='-', color='green', alpha=0.5, label='warm ana 1')

        """cold analytical line"""
        if plot_ana[1]:
            ax.axvline(1e4, lw=2, ls='-', color='blue', alpha=0.5, label='cold ana')
        
        """warm analytical line 2"""
        if plot_ana[2]:
            ax.axvline(2e6, lw=2, ls='-', color='red', alpha=0.5, label='warm ana 2')

    """Plot the timescales"""
    # load the csv file aand the trial names
    csvpath = f'{pickle_path.split('.')[0]}.csv'
    df = pd.read_csv(csvpath, comment='#')
    trials = df['trial'].to_numpy()

    # loop through the trials
    t_cc_hc, t_cc_wc, t_cc_hw = [], [], []
    t_grow_hc, t_grow_wc, t_grow_hw = [], [], []
    t_cool_wc, t_cool_hw = [], []
    
    for i, trial_mach in enumerate(df['x_mach'].to_numpy()):
        if (trial_mach < mach+0.1) and (trial_mach > mach-0.1):  # same criteria
            trial = trials[i]
            datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/{trial}'
            with open(f'{datapath}/params.pickle', 'rb') as handle:
                rp = pickle.load(handle)
            # cooling function
            import sys
            sys.path.append(os.path.abspath('/freya/ptmp/mpa/wuze/multiphase_turb/athena/cooling_scripts'))
            import cooling_fn as cf
            t_cool_func = lambda T : cf.tcool_calc(T_hot * 0.1 / T, T, Zsol=1.0, Lambda_fac=1.0, fit_type="max")
                
            # calculate t_cc of warm/cold gas
            T_cold = rp['T_cloud']
            T_hot = rp['T_hot']
            T_warm = 8000#np.sqrt(T_cold * T_hot)
            T_mix = np.sqrt(T_cold * T_hot)
            
            # calculate other quantities
            chi_hc = T_hot / T_cold
            chi_wc = T_warm / T_cold
            chi_hw = T_hot / T_warm
            R_cl = rp['cloud_radius']
            cloud_box_ratio = 1/50
            
            # load other values
            t_cool_min = 0.0001217175017901
            l_shat = 2.4989679118099205e-06
            vturb = rp['mach'] * calc_cs(T_hot)
            
            # calculate the four timescales
            t_cc_hc.append( (chi_hc ** (1/2) * R_cl / vturb) )
            t_cc_wc.append( (chi_wc ** (1/2) * R_cl / vturb) )
            t_cc_hw.append( (chi_hw ** (1/2) * R_cl / vturb) )
            
            t_grow_hc.append( chi_hc * rp['mach'] ** (-1/2) * (R_cl / l_shat)**(1/2) * cloud_box_ratio**(-1/6) * t_cool_func(T_warm) )
            t_grow_wc.append( chi_wc * rp['mach'] ** (-1/2) * (R_cl / l_shat)**(1/2) * cloud_box_ratio**(-1/6) * t_cool_func(T_cold) )
            t_grow_hw.append( chi_hw * rp['mach'] ** (-1/2) * (R_cl / l_shat)**(1/2) * cloud_box_ratio**(-1/6) * t_cool_min )

            # the cooling functions are altered
            t_cool_wc.append(t_cool_func(800) / (0.6 * mach))
            t_cool_hw.append(t_cool_func(8000) / (0.6 * mach))  # the cooling function limit for warm and cold
            
            # all the relevant timescales
            if verbose:
                print(f't_cc_hc   = {t_cc_hc:>10.3f}; rate = {1/t_cc_hc:>10.3e}')
                print(f't_cc_wc   = {t_cc_wc:>10.3f}; rate = {1/t_cc_wc:>10.3e}')
                print(f't_cc_hw   = {t_cc_hw:>10.3f}; rate = {1/t_cc_hw:>10.3e}')
                print(f't_grow_hc = {t_grow_hc:>10.3f}; rate = {1/t_grow_hc:>10.3e}')
                print(f't_grow_wc = {t_grow_wc:>10.3f}; rate = {1/t_grow_wc:>10.3e}')
                print(f't_grow_hw = {t_grow_hw:>10.3f}; rate = {1/t_grow_hw:>10.3e}')
                print(f't_cool_cloud = {t_cool_func(800):>10.3f}; rate = {1/t_cool_func(800):>10.3e}')
                print(f't_cool_peak = {t_cool_func(8000):>10.5f}; rate = {1/t_cool_func(8000):>10.3e}')

    ylist = ylist[:int(len(ylist)/2)]
    ylist_sorted = np.sort(ylist)
    """Plot the timescales"""
    # creates warm gas
    ax.plot(ylist_sorted, sort_parallel(t_cc_wc, ylist), lw=1, ls='-', alpha=0.5, color='green', label=r'$t_{\rm cc, wc}$')
    ax.plot(ylist_sorted, sort_parallel(t_cc_hc, ylist), lw=1, ls='--', alpha=0.5, color='green', label=r'$t_{\rm cc, hc}$')
    ax.plot(ylist_sorted, sort_parallel(t_grow_hw, ylist), lw=1, ls=':', alpha=0.5, color='green', label=r'$t_{\rm grow, hw}$')
    ax.plot(ylist_sorted, sort_parallel(t_cool_hw, ylist), lw=1, ls='-.', alpha=0.5, color='green', label=r'$t_{\rm cool, peak}$')

    # destroys warm gas
    ax.plot(ylist_sorted, sort_parallel(t_cc_hw, ylist), lw=1, ls='--', alpha=0.5, color='red', label=r'$t_{\rm cc, hw}$')
    ax.plot(ylist_sorted, sort_parallel(t_grow_wc, ylist), lw=1, ls=':', alpha=0.5, color='red', label=r'$t_{\rm grow, wc}$')
    ax.plot(ylist_sorted, sort_parallel(t_cool_wc, ylist), lw=1, ls='-.', alpha=0.5, color='red', label=r'$t_{\rm cool, cloud}$')
    
    ax.legend(loc='best', bbox_to_anchor=[0.9, 0.55, 0.5, 0.5], fontsize=10)
    # axis
    ax.set_xlim(np.power(10., 1), np.power(10., 8.5))
    ax.set_xscale('log')
    # ax.set_ylim(1e-4, 1e5)
    ax.set_yscale('log')
    ax.set_xlabel(r'$\frac{R_{\rm cl}}{l_{\rm shatter}}$')
    ax.set_ylabel('Timescales')

    """color bar"""
    # cold
    cbar_ax1 = fig.add_axes([0.925, 0.05, 0.02, 0.3])  # [left, bottom, width, height]
    cbar1 = plt.colorbar(scs[0], cax=cbar_ax1, extend='both')
    # cbar1.set_ticklabels([])
    cbar1.ax.set_xlabel('c', labelpad=10)
    # warm
    cbar_ax2 = fig.add_axes([1.025, 0.05, 0.02, 0.3])  # [left, bottom, width, height]
    cbar2 = plt.colorbar(scs[1], cax=cbar_ax2, extend='max')
    cbar2.ax.set_ylabel(r'$\log_{10} \frac{M_{\rm phase}}{M_{\rm cold, 0}}$', rotation=90, labelpad=10)
    cbar2.ax.set_xlabel('w', labelpad=1)
    
    plt.show()
    return (ylist_sorted, (np.array(t_cc_wc) * np.array(t_cc_hc) * t_cool_func(8000)) / (np.array(t_cc_hw) * t_cool_func(800)))

cm_cold = cmr.get_sub_cmap('cmr.viola_r', 0.25, 0.75)  #plt.colormaps['bwr_r']  # diverging colormap for cold gas
cm_warm = cmr.combine_cmaps(cmr.get_sub_cmap('cmr.wildfire', 0.5, 0.75), cmr.get_sub_cmap('cmr.wildfire', 0.75, 1), nodes=[1/3])#cmr.get_sub_cmap('cmr.ember', 0.6, 1, N=15)  #cmr.get_sub_cmap('cmr.ember', 0.3, 1, N=2)  #plt.colormaps['Oranges']  # diverging colormap for cold gas
ms = 50

x,y = \
plot_timescale_mach(pickle_path='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.pkl',
                    mach=0.4, pt_y=1e7,
                    cm_cold=cm_cold, cm_warm=cm_warm, ms=ms,
                    plot_ana=[1, 1, 1])  # analytical lines as predicted: [warm1, cold, warm2]

# %% [markdown]
# # Parameterization t_cc / t_cool

# %%
cm_cold = cmr.get_sub_cmap('cmr.viola_r', 0.25, 0.75)  #plt.colormaps['bwr_r']  # diverging colormap for cold gas
cm_warm = cmr.combine_cmaps(cmr.get_sub_cmap('cmr.wildfire', 0.5, 0.75), cmr.get_sub_cmap('cmr.wildfire', 0.75, 1), nodes=[1/3])#cmr.get_sub_cmap('cmr.ember', 0.6, 1, N=15)  #cmr.get_sub_cmap('cmr.ember', 0.3, 1, N=2)  #plt.colormaps['Oranges']  # diverging colormap for cold gas
ms = 50

from codes.plotting.params import *
plot_params_coolmix_cc(csvpath='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv',
                       cm_cold=cm_cold, cm_warm=cm_warm, ms=ms,
                       plot_ana=True, show_text=False, real_mach=True)
# Out:
# KeyboardInterrupt
# Error in callback <function _draw_all_if_interactive at 0x1482f3d86480> (for post_execute), with arguments args (),kwargs {}:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x14845a731790>>
# Traceback (most recent call last):
#   File "/freya/ptmp/mpa/wuze/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
#
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x1482f3d9a480> (for post_execute), with arguments args (),kwargs {}:
# KeyboardInterrupt

# %% [markdown]
# ## Quick plot

# %%
cm_cold = cmr.get_sub_cmap('cmr.viola_r', 0.25, 0.75)  #plt.colormaps['bwr_r']  # diverging colormap for cold gas
cm_warm = cmr.combine_cmaps(cmr.get_sub_cmap('cmr.wildfire', 0.5, 0.75), cmr.get_sub_cmap('cmr.wildfire', 0.75, 1), nodes=[1/3])#cmr.get_sub_cmap('cmr.ember', 0.6, 1, N=15)  #cmr.get_sub_cmap('cmr.ember', 0.3, 1, N=2)  #plt.colormaps['Oranges']  # diverging colormap for cold gas
ms = 50

from codes.plotting.params import *
plot_params_coolmix_cc_save(pickle_path=f'/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new_timescales.pkl',
                            log_ylimu=9, ms=ms, plot_ana=True, show_text=True,
                            cm_cold=cm_cold, cm_warm=cm_warm, verbose=True)

# %% [markdown]
# ## Timescale plots

# %%
def plot_timescales(trial = '', verbose = False, t_cc = 0):
    datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/{trial}'
    with open(f'{datapath}/params.pickle', 'rb') as handle:
        rp = pickle.load(handle)

    # Import the cooling function from Hitesh's scripts
    import sys
    sys.path.append(os.path.abspath('/freya/ptmp/mpa/wuze/multiphase_turb/athena/cooling_scripts'))
    import cooling_fn as cf
    sys.path.append(os.path.abspath('/freya/ptmp/mpa/wuze/multiphase_turb/athena/helper_scripts'))
    import v_turb as vt

    # temperature range
    T_arr = np.logspace(np.log10(rp['T_floor']),
                        np.log10(rp['T_ceil']), 100)  # in kelvin
    rho_arr = rp['rho_hot'] * rp['T_hot'] / T_arr
    
    """
    Cooling & Heating functions
    """
    Gamma_n_arr = 1e-26 / rho_arr
    Lambda_arr = np.vectorize(cf.Lam_fn_powerlaw)(T_arr, Zsol=1.0, Lambda_fac=1.0)
    
    """
    Cooling & Heating rates
    """
    heating_rate = 1e-26 * rho_arr
    cooling_rate = Lambda_arr * rho_arr**2
    
    """
    Timescale
    """
    tcool_arr = np.vectorize(cf.tcool_calc)(
        rho_arr, T_arr, Zsol=1.0, Lambda_fac=1.0, fit_type="max"
    )

    """
    Shattering length
    """
    def calc_cs(T):
        m_to_cm = 100
        return np.sqrt(u.g * u.CONST_kB / (u.mu * u.CONST_amu) * T) / u.unit_velocity
    t_cool_func = lambda T : cf.tcool_calc(rp['rho_hot'] * rp['T_hot'] / T, T, Zsol=1.0, Lambda_fac=1.0, fit_type="max")
    l_shatter = np.vectorize(t_cool_func)(T_arr) * calc_cs(T_arr)

    """
    Minimum l_shatter
    """
    # calculate geometric mean T_mix
    # the two limits
    T_cold = rp['T_cloud']  # set cold temperature to that of cloud
    T_hot = rp['T_hot']

    """T_mix calculations"""
    # the params in range
    T_ind_low, T_ind_high = find_ind_l(T_arr, T_cold), find_ind_l(T_arr, T_hot)
    T_range = T_arr[T_ind_low : T_ind_high]
    tcool_range = tcool_arr[T_ind_low : T_ind_high]
    
    T_tcoolmin = T_range[np.argmin(tcool_range)]  # the temperature corresponding to the lowest t_cool
    T_mix = np.sqrt(T_tcoolmin * T_hot)  # use the temperature at which t_cool is lowest instead of this:  # T_mix = np.sqrt(T_cold * T_hot)  # use the cloud temperature

    t_cool_min = np.min(tcool_range)
    t_cool_mix = t_cool_func(T_mix)
    t_cool_cold = t_cool_func(T_cold)
    
    l_shatter_min = np.min(l_shatter[T_ind_low : T_ind_high])

    if verbose:
        print(f'T_cold = {T_cold}')
        print(f'T_hot = {T_hot:.2e}')
        print(f'T_mix = {T_mix:.2e}')
        print(f't_cool,mix,og = {t_cool_func(np.sqrt(T_cold * T_hot)):.2e}')
        print(f't_cool,mix = {t_cool_mix:.2e}')
        print(f't_cool,cold = {t_cool_cold:.2e}')
        print(f't_cool_min = {t_cool_min:.2e}')
        print(f'l_shatter_min = {l_shatter_min:.2e}')
    
    def plot_tvlines():
        plt.axvline(x=rp['T_floor'], lw=1, color="k", linestyle="--")
        plt.axvline(x=rp['T_cloud'], lw=1, color="slateblue", linestyle="--")
        plt.axvline(x=T_tcoolmin, lw=1, color="slateblue", linestyle="-.", alpha=0.2)
        plt.axvline(x=T_mix, lw=1, color="green", linestyle="-.", alpha=0.2)
        plt.axvline(x=rp['T_hot'], lw=1, color="orangered", linestyle="--")
        # plt.axvline(x=T_cut color="k", linestyle="")
    
    """Cooling timescale"""
    plt.figure(figsize=(4, 3))
    
    plt.plot(T_arr, tcool_arr, label=r"$\Lambda(T)$")
    plt.ylabel(r"$t_{\rm cool} [u]$", fontsize=14)
    plt.xlabel(r"$T$(K)", fontsize=14)
    plt.yscale("log")
    plt.xscale("log")
    plot_tvlines()
    # plot the t_cc intersection lines
    t_cc = rp['t_cc'] if not t_cc else t_cc  # if no initialization
    print(t_cc)
    T_actual = T_arr[-find_ind_l(-tcool_arr[::-1], -t_cc)]
    ratio_actual = T_actual / T_mix
    print(f'T_actual = {T_actual:.3e}, ratio = {ratio_actual}')
    plt.axhline(t_cc, ls='--', lw=1, c='k', alpha=0.3, label=r'$t_{\rm cc}$')
    plt.axvline(T_actual, ls='--', lw=1, c='k', alpha=0.3)
    plt.text(1e8, t_cc * 2, r'$t_{\rm cc}$', c='k', alpha=0.8, ha='right', va='bottom')
    plt.show()

    return T_actual, ratio_actual

# %% [markdown]
# ### Cold
#
# * Hot gas disappears
# * Warm / cold interactions

# %%
trial = '240716_0.8_8000'
datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/{trial}'
with open(f'{datapath}/params.pickle', 'rb') as handle:
    rp = pickle.load(handle)
    
# calculate t_cc of warm/cold gas
T_cold = rp['T_cloud']
T_hot = rp['T_hot']
T_warm = 8000#np.sqrt(T_cold * T_hot)

chi_wc = T_warm / T_cold
vturb = rp['mach'] * calc_cs(T_hot)
t_cc_wc = (chi_wc ** (1/2) * rp['cloud_radius'] / vturb)
print(rp['t_cc'], t_cc_wc)
# Out:
# 5.686218879494352 0.25429543898984114

# %%
ratio_tcc = np.sqrt(T_hot / T_warm)
ratio_tcc
# Out:
# 22.360679774997898

# %%
# destroyed
_, ratio =\
plot_timescales('240716_0.8_8000', verbose=False, t_cc = t_cc_wc)
# Out:
# 0.25429543898984114
# T_actual = 9.820e+05, ratio = 3.7175785660396055

# %%
# survives
_, ratio =\
plot_timescales('240711_0.4_16000', verbose=False, t_cc = t_cc_wc)
# Out:
# 1.0171817559593646
# T_actual = 1.776e+06, ratio = 6.724807440084015

# %% [markdown]
# ### Warm 1

# %%
trial = '240711_0.8_1600'
datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/{trial}'
with open(f'{datapath}/params.pickle', 'rb') as handle:
    rp = pickle.load(handle)
    
# calculate t_cc of hot/warm gas
T_cold = rp['T_cloud']
T_hot = rp['T_hot']
T_warm = 8000#np.sqrt(T_cold * T_hot)

chi_hw = T_hot / T_warm
vturb = rp['mach'] * calc_cs(T_hot)
t_cc_hw = (chi_hw ** (1/2) * rp['cloud_radius'] / vturb)
print(rp['t_cc'], t_cc_hw)
# Out:
# 1.1372437758988703 0.3596280586690533

# %%
# destroyed
_, ratio =\
plot_timescales('240715_0.8_16', verbose=False, t_cc = t_cc_hw)
# Out:
# 0.0035962805866905333
# T_actual = 2.103e+05, ratio = 0.7961024155997622

# %%
# survives
_, ratio =\
plot_timescales('240711_0.8_1600', verbose=False, t_cc = t_cc_hw)
# Out:
# 0.3596280586690533
# T_actual = 1.106e+06, ratio = 4.185468666613223

# %% [markdown]
# ### Warm 2

# %% [markdown]
# #### Investigating a single trial
#
# 240711_0.8_1600000

# %%
print_timescales(trial = '240711_0.4_160000000'), func(trial = '240711_0.4_1600000'),\
print_timescales(trial = '240715_0.4_160000'), func(trial = '240716_0.4_64000'), func(trial = '240711_0.4_16000') # this is when it's destroyed!
# Out:
# t_cc_hc   = 227448.755; rate =  4.397e-06
# t_cc_wc   =  10171.818; rate =  9.831e-05
# t_cc_hw   =  71925.612; rate =  1.390e-05
# t_grow_hc = 19457624.011; rate =  5.139e-08
# t_grow_wc =   1554.187; rate =  6.434e-04
# t_grow_hw =   2336.708; rate =  4.280e-04
# t_cool_wc =      0.004; rate =  9.866e+00
# t_cool_hw =    0.10135; rate =  9.866e+00
# -0.00013106301805100888
#
#
#
#
#
#
# t_cc_hc   =   2274.488; rate =  4.397e-04
# t_cc_wc   =    101.718; rate =  9.831e-03
# t_cc_hw   =    719.256; rate =  1.390e-03
# t_grow_hc = 1945762.401; rate =  5.139e-07
# t_grow_wc =    155.419; rate =  6.434e-03
# t_grow_hw =    233.671; rate =  4.280e-03
# t_cool_wc =      0.004; rate =  9.866e+00
# t_cool_hw =    0.10135; rate =  9.866e+00
# 0.00628605325250747
#
#
#
#
#
#
# t_cc_hc   =    227.449; rate =  4.397e-03
# t_cc_wc   =     10.172; rate =  9.831e-02
# t_cc_hw   =     71.926; rate =  1.390e-02
# t_grow_hc = 615304.097; rate =  1.625e-06
# t_grow_wc =     49.148; rate =  2.035e-02
# t_grow_hw =     73.893; rate =  1.353e-02
# t_cool_wc =      0.004; rate =  9.866e+00
# t_cool_hw =    0.10135; rate =  9.866e+00
# 0.07759381468055862
#
#
#
#
#
#
# t_cc_hc   =     90.980; rate =  1.099e-02
# t_cc_wc   =      4.069; rate =  2.458e-01
# t_cc_hw   =     28.770; rate =  3.476e-02
# t_grow_hc = 389152.480; rate =  2.570e-06
# t_grow_wc =     31.084; rate =  3.217e-02
# t_grow_hw =     46.734; rate =  2.140e-02
# t_cool_wc =      0.004; rate =  9.866e+00
# t_cool_hw =    0.10135; rate =  9.866e+00
# 0.20024545366292754
#
#
#
#
#
#
# t_cc_hc   =     22.745; rate =  4.397e-02
# t_cc_wc   =      1.017; rate =  9.831e-01
# t_cc_hw   =      7.193; rate =  1.390e-01
# t_grow_hc = 194576.240; rate =  5.139e-06
# t_grow_wc =     15.542; rate =  6.434e-02
# t_grow_hw =     23.367; rate =  4.280e-02
# t_cool_wc =      0.004; rate =  9.866e+00
# t_cool_hw =    0.10135; rate =  9.866e+00
# 0.8225288758268307
# (None, None, None, None, None)

# %%
"""calculate the four timescales"""
# load run properties
trial = '240711_0.4_160000000'
datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/{trial}'
with open(f'{datapath}/params.pickle', 'rb') as handle:
    rp = pickle.load(handle)
rp, x, y, t_cool_mix, t_cool_min, [t_cool_func, T_tcoolmin, T_mix] = add_point(trial=trial, verbose=False)
    
# calculate t_cc of warm/cold gas
T_cold = rp['T_cloud']
T_hot = rp['T_hot']
T_warm = 8000#np.sqrt(T_cold * T_hot)

# calculate other quantities
chi_wc = T_warm / T_cold
chi_hw = T_hot / T_warm
mach = rp['mach']
R_cl = rp['cloud_radius']
cloud_box_ratio = 1/50

# load other values
t_cool_min = 0.0001217175017901
l_shat = 2.4989679118099205e-06
vturb = rp['mach'] * calc_cs(T_hot)

# calculate the four timescales
t_cc_wc = (chi_wc ** (1/2) * R_cl / vturb)
t_cc_hw = (chi_hw ** (1/2) * R_cl / vturb)

t_grow_wc = chi_wc * mach**(-1/2) * (R_cl / l_shat)**(1/2) * cloud_box_ratio**(-1/6) * t_cool_func(800)
t_grow_hw = chi_hw * mach**(-1/2) * (R_cl / l_shat)**(1/2) * cloud_box_ratio**(-1/6) * t_cool_min

print(f't_cc_wc   = {t_cc_wc:>10.3f}; rate = {1/t_cc_wc:>10.3e}')  # add
print(f't_cc_hw   = {t_cc_hw:>10.3f}; rate = {1/t_cc_hw:>10.3e}')  # subtract
print(f't_grow_wc = {t_grow_wc:>10.3f}; rate = {1/t_grow_wc:>10.3e}')  # subtract
print(f't_grow_hw = {t_grow_hw:>10.3f}; rate = {1/t_grow_hw:>10.3e}')  # add
# Out:
# t_cc_wc   =  10171.818; rate =  9.831e-05
# t_cc_hw   =  71925.612; rate =  1.390e-05
# t_grow_wc =   1554.187; rate =  6.434e-04
# t_grow_hw =   2336.708; rate =  4.280e-04

# %%
(1/t_cc_wc + 1/t_cool_min - 1/t_cc_hw - 1/t_cool_func(8000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 (1/t_cc_wc + 1/t_cool_min - 1/t_cc_hw - 1/t_cool_func(8000))
#
# NameError: name 't_cc_hw' is not defined

# %%
# growth criteria of cold gas
cold_crit = t_cc_wc / t_cool_func(T_warm)

# growth criteria of warm gas
warm_crit = t_cc_hw / t_cool_func(T_tcoolmin)

cold_crit
# Out:
# 0.10135343570552248

# %%
dwarm_dt = (1/t_grow_hw - 1/t_grow_wc) / (1/t_cc_hw - 1/t_cc_wc)
print(f'{dwarm_dt}')
# Out:
# -4.765634031048372

# %% [markdown]
# #### Others

# %%
trial = '240711_0.4_160000000'
datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/{trial}'
with open(f'{datapath}/params.pickle', 'rb') as handle:
    rp = pickle.load(handle)
    
# calculate t_cc of warm/cold gas
T_cold = rp['T_cloud']
T_hot = rp['T_hot']
T_warm = 8000#np.sqrt(T_cold * T_hot)

chi_wc = T_warm / T_cold
vturb = rp['mach'] * calc_cs(T_hot)
t_cc_wc = (chi_wc ** (1/2) * rp['cloud_radius'] / vturb)
print(rp['t_cc'], t_cc_wc)
# Out:
# 227448.7551797741 10171.817559593646

# %%
# survives
_, ratio =\
plot_timescales('240711_0.8_1600000', verbose=False, t_cc=t_cc_wc)
# Out:
# 50.85908779796823
# T_actual = 5.813e+06, ratio = 22.004892355468314

# %%
# destroyed
_, ratio =\
plot_timescales('240711_0.4_160000000', verbose=False, t_cc=t_cc_wc)
# Out:
# 10171.817559593646
# T_actual = 7.889e+07, ratio = 298.6523373047889

# %% [markdown]
# # Growth evolution plots

# %% [markdown]
# ## All one mach
#
# Plot growth of cold & warm gas for a particular trial

# %%
from codes.plotting.growth import *
plot_evol_all_both(csvpath=f'/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv', mach=0.6, plot_wg=True)
# Out:
# [1.         0.99959152 0.9990737  ... 0.         0.         0.        ]
# [1.00000000e+00 9.93182802e-01 9.86672197e-01 ... 9.30087650e-06
#  7.50042382e-06 4.90013165e-06]
# [1.         0.99317559 0.98665416 ... 0.2371678  0.23668879 0.23885875]
# [1.         0.99951731 0.99817481 ... 2.48798166 2.48780065 2.48577182]
# [1.         0.99812956 0.99664376 ... 5.89843803 5.89742739 5.89778941]
# [1.         1.00003771 1.00010559 ... 7.00233051 7.00313752 7.00278304]

# %% [markdown]
# ## Particular trials
#
# Plot evolution of WARM & COLD gas mass for a trial on the same plot

# %%
from codes.plotting.growth import *
plot_evol_both_trial(csvpath='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv',
                     trial='240715_0.8_16')

# %% [markdown]
# # Actual mach number

# %%
trial = '240711_0.8_320'

from codes.plotting.checks import *
check_vturb_mach(trial=trial)
# Out:
# /freya/ptmp/mpa/wuze/multiphase_turb/codes/plotting/checks.py:55: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()
# 0.10648235241990567

# %% [markdown]
# # Cloud evol plot

# %% [markdown]
# ## Growth rate estimate

# %%
def plot_exp_growth_rate(ax, time_arr_eddy, csvpath = '/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e3.csv', mach = 0.3, alpha = 0.5):
    import pandas as pd
    df = pd.read_csv(csvpath, comment='#')
    df['yval'] = df["r_cl"] / df["l_shat"]
    df.sort_values(by='yval', inplace=True)
    xys, cs = [], []
    fig, ax1 = plt.subplots(figsize=(5,3))
    cm = plt.colormaps['BrBG_r']  # colormap for the gas fractions
    
    for _, row in df.iterrows():
        if row['x_mach'] != mach:
            continue
        datapath = f'/freya/ptmp/mpa/wuze/multiphase_turb/data/{row['trial']}'

        # load run parameters
        with open(f'{datapath}/params.pickle', 'rb') as handle:
            rp = pickle.load(handle)
    
        # load t_cool_min
        l_shatter_min, t_cool_mix, t_cool_min, [t_cool_func, T_tcoolmin, T_mix] = load_lshat(rp=rp, verbose=False)

        # growth time
        t_grow = alpha * rp['chi'] *\
        (rp['mach'] ** -1/2) *\
        (df['yval'] ** 1/2) *\
        (rp['box_size'] / rp['cloud_radius'] ** 1/6) *\
        t_cool_min

        # time_arr in eddie time
        time_arr = time_arr_eddy
        cold_frac = np.exp(time_arr / t_cool_min)
        ax.plot(time_arr_eddy, cold_frac, lw=1, ls='-.', alpha=0.2, color='k')

# %% [markdown]
# ## Basic

# %%
import cmasher as cmr
r_cl_cm = cmr.get_sub_cmap('cmr.pride', 0, 1)

growth_temps=[8e3, 8e2]
# growth_temps=[4e6, 8e2]

from codes.plotting.growth import *
plot_evol_all_cold(csvpath='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv', mach=0.4, cm=r_cl_cm,
                   verbose=False, plot_growth=0, growth_temps=growth_temps)
plt.show()

# %%
import cmasher as cmr
r_cl_cm = cmr.get_sub_cmap('cmr.pride', 0, 1)

growth_temps=[8e3, 8e2]
# growth_temps=[4e6, 8e2]

from codes.plotting.growth import *

ax, x, time = \
plot_evol_all_cold(csvpath='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv', mach=0.4, cm=r_cl_cm,
                   verbose=False, plot_growth=0, growth_temps=growth_temps)


t_grow_calc = 1e5
cold_frac = np.exp(time / t_grow_calc)
ax.plot(x, cold_frac, lw=1, ls=':', alpha=0.5, color='k')

plt.show()

# %%
# using eq 7

mach = 0.4
yval = 1.6e8

T_peak = 8.57e+03
t_cool_peak = 1e-1
t_cool_min = 1e-4
chi_growth = 8000 / 800

t_grow = 0.5 * chi_growth ** (3/4) *\
(mach ** (-1/2)) *\
(yval ** (1/2)) *\
((1/50) ** (1/6)) *\
t_cool_min

t_grow  # TOO FAST!
# Out:
# 2.9298024147245108

# %%
# using eq 6

# equivalent t_cool
Rcl = 400
chi_hot_cold = 4e6 / 8e2

v_turb_hot = 0.1244
v_turb_cold = v_turb_hot * (1/50)**(1/3)
print(v_turb_cold)

# use cs instead
cs_cold = calc_cs(800)
v_turb_cold = cs_cold
print(v_turb_cold)

t_cool_eq = ((Rcl / v_turb_cold) * t_cool_peak) ** (1/2)

chi_growth * t_cool_eq
# Out:
# 0.03376735515044064
# 0.004396594737173243
# 30.162808568153867

# %% [markdown]
# ## With different cold gas temperatures

# %%
from codes.plotting.growth import *

# %%
# Choose within cold_cloud_ratio_list = [2, 3, 5, 10]
plot_evol_all_ratio(mach=0.3, cold_cloud_ratio=3)

# %%
from codes.plotting.growth import *
plot_evol_both_trial(csvpath='/freya/ptmp/mpa/wuze/multiphase_turb/data/saves/cloud_8e2_new.csv',
                     trial='240709_0.6_1600000')
